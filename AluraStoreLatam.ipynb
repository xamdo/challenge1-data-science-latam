# %% [markdown]
# ### Importación de datos

# %%
##pip install pandas

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
df = pd.concat([tienda, tienda2, tienda3, tienda4], ignore_index = True)

df.columns = (
    df.columns
    .str.strip()
    .str.lower()
    .str.replace(' ', '_')
    .str.normalize('NFKD')
    .str.encode('ascii', errors='ignore')
    .str.decode('utf-8')
)

facturacion_total = df.groupby('lugar_de_compra')['precio'].sum().reset_index()
facturacion_total.columns = ['lugar_de_compra','facturacion_total']
print(facturacion_total)
# Out:
#    lugar_de_compra  facturacion_total
# 0          Armenia       1.224290e+07
# 1     Barranquilla       1.320405e+08
# 2           Bogotá       1.814858e+09
# 3      Bucaramanga       9.057330e+07
# 4             Cali       5.065261e+08
# 5        Cartagena       1.023767e+08
# 6           Cúcuta       9.936910e+07
# 7          Inírida       8.087900e+06
# 8          Leticia       6.714990e+07
# 9        Manizales       1.936790e+07
# 10        Medellín       1.096669e+09
# 11           Neiva       2.089800e+07
# 12           Pasto       4.901430e+07
# 13         Pereira       2.259273e+08
# 14        Riohacha       7.387970e+07
# 15     Santa Marta       5.310050e+07
# 16          Soacha       1.231770e+07
# 17      Valledupar       5.886300e+06
# 18   Villavicencio       1.333360e+07

# %% [markdown]
# # 2. Ventas por categoría

# %%
categorias_populares = df['categoria_del_producto'].value_counts().reset_index()
categorias_populares.columns = ['Categoria', 'total_vendidos']
print(categorias_populares)
# Out:
#                  Categoria  total_vendidos
# 0                  Muebles            1886
# 1             Electrónicos            1772
# 2                 Juguetes            1290
# 3        Electrodomésticos            1149
# 4     Deportes y diversión            1113
# 5   Instrumentos musicales             753
# 6                   Libros             742
# 7  Artículos para el hogar             730

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
calificacion_promedio = df.groupby('categoria_del_producto')['calificacion'].mean().reset_index()
print(calificacion_promedio)
# Out:
#     categoria_del_producto  calificacion
# 0  Artículos para el hogar      3.979452
# 1     Deportes y diversión      3.988320
# 2        Electrodomésticos      4.014795
# 3             Electrónicos      3.992664
# 4   Instrumentos musicales      4.003984
# 5                 Juguetes      4.070543
# 6                   Libros      4.004043
# 7                  Muebles      4.033934

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
producto_mas_vendido = df['producto'].value_counts().head(5)
producto_menos_vendido = df['producto'].value_counts().tail(5)
print('#==los cinco productos mas vedidos==#')
print(producto_mas_vendido)
print('#==los cinco producto menos vendido==#')
print(producto_menos_vendido)
# Out:
# #==los cinco productos mas vedidos==#
# producto
# Mesa de noche                210
# Carrito de control remoto    206
# Microondas                   206
# Batería                      203
# Cama king                    201
# Name: count, dtype: int64
# #==los cinco producto menos vendido==#
# producto
# Ciencia de datos con Python    166
# Guitarra eléctrica             165
# Mochila                        163
# Auriculares con micrófono      158
# Celular ABXY                   157
# Name: count, dtype: int64

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
envio_promedio = df['costo_de_envio'].mean()
print('El costo de envio promedio general es:')
print(envio_promedio)
round(envio_promedio, 2)
# Out:
# El costo de envio promedio general es:
# 24875.145733969264
# np.float64(24875.15)

# %%
envio_promedio_tienda = df.groupby('lugar_de_compra')['costo_de_envio'].mean().reset_index()
print('costo promedio de envio por tienda es')
print(envio_promedio)
# Out:
# costo promedio de envio por tienda es
# 24875.145733969264
